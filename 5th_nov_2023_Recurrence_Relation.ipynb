# %%
#Question 1


Substitute values to find T(1):

T(1)=3T(0)+12⋅1

Substitute T(0)=5 into the equation:

T(1)=3⋅5+12⋅1=15+12=27

Substitute values to findT(2):

T(2)=3T(1)+12⋅2

Substitute T(1)=27 into the equation:

T(2)=3⋅27+12⋅2=81+24=105


Therefore, the value of T(2) for the given recurrence relation with the initial condition is 105.

# %%
Let's solve each recurrence relation using the substitution :
T(n)=T(n−1)+c
Base Case:
T(0) is needed to start the substitution. Given that it is not provided, we'll assume 

T(0)=0 for simplicity.

Substitution
a.T(n)=T(n−1)+c
=(T(n−2)+c)+c
=T(n−2)+2c
=T(n−3)+3c
⋮
=T(0)+nc
=nc
So,T(n)=nc.

b.T(n)=2T(n/2)+n
Base Case:
T(1) is needed for the base case. If n=1, then T(1)=1.

Substitution:
T(n)=2T(n/2)+n
=2(2T(n/4)+n/2)+n
=2^2T(n/4)+2n
=2^3T(n/8)+3n
⋮
=2^log^2&^nT(1)+log^2n⋅n
=n+nlog^2^n
​
 
So,T(n)=n+nlog^2n.

c.T(n)=2T(n/2)+c
Base Case:

T(1) is needed for the base case. If n=1, then T(1)=c.

Substitution:

T(n)=2T(n/2)+c
=2(2T(n/4)+c)+c
=2^2T(n/4)+3c
=2^3T(n/8)+7c
⋮
=2^log^nT(1)+(2^log^2^n−1)c
=n⋅c+(n−1)c
=nc
​
 
So,T(n)=nc.

d.T(n)=T(n/2)+c
Base Case:
T(1) is needed for the base case. If n=1, then T(1)=c.

Substitution:
T(n)=T(n/2)+c
=(T(n/4)+c)+c
=T(n/4)+2c
=T(n/8)+3c
⋮
=T(1)+log^2 n⋅c
=c+log^2 n⋅c
=c(1+log^2 n)
​
 
So, T(n)=c(1+log^2n).

In summary:

For a,T(n)=nc.
For b,T(n)=n+nlog^2 n.
For c,T(n)=nc.
For d,T(n)=c(1+log^2 n).

# %%
#Question 3

a.T(n)=2T(n−1)+1
T(n) = 2^n * T(1) + 2^(n-1) * 1 + 2^(n-2) * 1 + ... + 1
     = 2^n * T(1) + 2^n - 1
     = 2^n * T(1) + O(2^n)
So,T(n)=2^n dominates the time complexity.

b.T(n)=2T(n/2)+n
T(n) = n * T(1) + n/2 * n/2 + n/4 * n/4 + ... + 1
     = n * T(1) + n^2/4 + n^2/16 + ... + 1
     = n * T(1) + O(n^2)+ O(n^2)
So, T(n)=n^2 dominates the time complexity.

In summary
For a, T(n)=2^n+O(2n).
For b, T(n)=n^2+O(n^2)
